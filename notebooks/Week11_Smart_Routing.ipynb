# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from llm.router import build_ticket

# %%
incident_text = """
There was a 20-minute delay on Line B at Carlos Pellegrini due to a mechanical failure.
Passengers reported overcrowding on the platform.
"""

llm_output = {
    "category": "infrastructure",
    "severity": "high",
    "line": "B",
    "station": "Carlos Pellegrini",
    "target_team": "manual_review",
    "confidence": 0.87,
}

# %%
ticket = build_ticket(incident_text, llm_output)
ticket
# Out:
# {'ticket_id': 'TCK-20251223214839',
#  'created_at': '2025-12-23T21:48:39.557142',
#  'source': 'llm_router',
#  'description': '\nThere was a 20-minute delay on Line B at Carlos Pellegrini due to a mechanical failure.\nPassengers reported overcrowding on the platform.\n',
#  'category': 'infrastructure',
#  'severity': 'high',
#  'line': 'B',
#  'station': 'Carlos Pellegrini',
#  'target_team': 'operations_control',
#  'confidence': 0.87,
#  'raw_llm_output': {'category': 'infrastructure',
#   'severity': 'high',
#   'line': 'B',
#   'station': 'Carlos Pellegrini',
#   'target_team': 'operations_control',
#   'confidence': 0.87}}
